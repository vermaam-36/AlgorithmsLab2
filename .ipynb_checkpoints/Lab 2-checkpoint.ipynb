# %% [markdown]
# # Lab 2: Iterative Algorithms
# ## CS 3851 Algorithms
# ## Amish Verma, Dylan Schultz, Gavin Vaubel, Michael Salgado

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from operator import truediv
import numpy as np
import time

# %% [markdown]
# ## 1. Decision Rule
# ![Screenshot%202022-03-29%20164736.png](attachment:Screenshot%202022-03-29%20164736.png)
#
# Given a 100x100 2D plane. For any polygon with points {p1, p2...pn} n >= 3 and point m {x,y} 0 <= x <= 100, 0 <= y <= 100.
#
# Let 4 lines be drawn outward from point m, one horizontal vector represented as a line.
#
# If the vector touchs lines created by the polygon points {p1, p2...pn} and odd amount of times then the point m lies within the polygon else point m lies outside the polygon
#
# Run Time Analysis:
# The algorithm runs in O(n) time as a worst case dependent on the number of points the polygon has if there is no polygon then we see a best case complexity of O(1) as the for loop will never be tripped. The line intersection method called inside the algorithm has a complexity of O(1) best and worst case.

# %% [markdown]
# ## 2. Psuedocode

# %% [raw]
# Func check_inside(polygon, st_pt):
# 	Horizontal_line = horizontal line from st_pt
#
# 	Intersections=0
#
# For each point in polygon:
# 	point1= point
# 	point2= polygon.nextPoint
# 	if(point2 == null) {
# 		Point2 == polygon[0]
# 	}
#
# 	polygon_line=solve( point1, point2)
#
# 	intersection_point=solve(vertical_line, polygon_line)
# 	if(intersection_point exists){
#
# 		intersection++
# 	}
#
# if(intersections%2 = = 1){
# 	Return true;
# }
# Return false;

# %% [markdown]
# ## 3. Explanation

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Find max and min, check if intersectio npoint is within max and min

# %%
def check_inside(polygon, st_pt):
    x_min = min(polygon)[0] # 1
    x_max = max(polygon)[0] # + 1
    horizontal_line= [0, 1, st_pt[1]] # + 1
    intersections= 0 # + 1

    for i in range(0, len(polygon)): #1 + n(1 
        point1=polygon[i] # + 1
        if(i != len(polygon) - 1): # + 1 + b(1)
            point2=polygon[i+1]
        else: # + 1 - b(1)
            point2=polygon[0]
        
        polygon_line= create_line(point1, point2) # + 1
        intersection_point=findIntersection(polygon_line, horizontal_line, st_pt) # + 1 + O(1) <- from findIntersection()
        print(f"polygon line: {polygon_line}") # + 1
        print(f"horizontal line: {horizontal_line}") # + 1
        print(f"intersection_point: {intersection_point}\n") # + 1

       
        if(intersection_point is not None): # + 1 + b(
             
            if(intersection_point[0]==point2[0] and intersection_point[1]==point2[1]): # 1 + b(3)
                intersections+=0
                #This is the double count case
            elif(intersection_point[0]>st_pt[0] and (intersection_point[0]<point1[0] or intersection_point[0]<point2[0])): # + 1 + b(3
                if(x_max >= intersection_point[0] >= x_min): # + 1 + b(2)
                    intersections+=1
        print(f"intersection: {intersections}\n") # + 1 + 1) + 1

    if(intersections%2 == 1): # + 1 + b(2)
        print(intersections)
        return True
    

    return False # + 1
#T(n) = 1 + 1 + 1 + 1 + 1 + n(1 + 1 + b(1) + 1 - b(1) + 1 + 1 + O(1) + 1 + 1 + 1 + 1 + b(1 + b(3) + 1 + b(2)) + 1 + 1) + 1 + 1 + b(2) + 1
#T(n) = 10 + 20n in O(n) worst and O(1) if there is no polygon to check

# %%
p1 = (1,4)
p2 = (1,7)
max(p1[1], p2[1])
# Out:
# 7

# %%
def create_line(pt1, pt2):
    print(f"pt1: {pt1}")
    print(f"pt2: {pt2}")


    x1 = pt1[0]
    y1 = pt1[1]

    x2 = pt2[0]
    y2 = pt2[1]

    a = y2 - y1
    b = x1 - x2

    c = (a * x1) + (b * y1)
    return np.array([a, b, c])

# %%
def findIntersection(poly, checker, st_pt):
    try: #1 + a(
        if(poly[0] == 0 and poly[1] % checker [1] == 0 and poly[2] % checker[2] == 0): # + 1 + b(1)
            return None
        
        m_list = [[poly[0], poly[1]], [checker[0], checker[1]]] # + 1
        A = np.array(m_list) # + 1
        inv_A = np.linalg.inv(A) # + 1
#         print(inv_A)
        B = np.array([poly[2], checker[2]]) # + 1
        X = np.linalg.inv(A).dot(B) # + 1
#         print(X)
        return X # + 1
    except: # + 1)
        return # + 1       T(n) = 1 + a(1 + b(1) + 1 + 1 + 1 + 1 + 1 + 1 + 1) + 1 = 8 = O(1) worst and best case

# %% [markdown]
# ## Experiment

# %% [markdown]
# ## Outside polygon test

# %%
coord = [(4,1), (4,5), (1,3)]
poly_coord = coord
st_pt = (2, 4)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

# Plotting Figure
plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()
check_inside(coord[:-1], st_pt)
# Out:
# pt1: (4, 1)
# pt2: (4, 5)
# polygon line: [ 4  0 16]
# horizontal line: [0, 1, 4]
# intersection_point: [4. 4.]
#
# intersection: 0
#
# pt1: (4, 5)
# pt2: (1, 3)
# polygon line: [-2  3  7]
# horizontal line: [0, 1, 4]
# intersection_point: [2.5 4. ]
#
# intersection: 1
#
# pt1: (1, 3)
# pt2: (4, 1)
# polygon line: [ -2  -3 -11]
# horizontal line: [0, 1, 4]
# intersection_point: [-0.5  4. ]
#
# intersection: 1
#
# 1
# True

# %% [markdown]
# ## Inside polygon test

# %%
coord = [(4,1), (4,5), (1,3)]
st_pt = (2, 3)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord[:-1], st_pt)
# Out:
# pt1: (4, 1)
# pt2: (4, 5)
# polygon line: [ 4  0 16]
# horizontal line: [0, 1, 3]
# intersection_point: [4. 3.]
#
# intersection: 0
#
# pt1: (4, 5)
# pt2: (1, 3)
# polygon line: [-2  3  7]
# horizontal line: [0, 1, 3]
# intersection_point: [1. 3.]
#
# intersection: 0
#
# pt1: (1, 3)
# pt2: (4, 1)
# polygon line: [ -2  -3 -11]
# horizontal line: [0, 1, 3]
# intersection_point: [1. 3.]
#
# intersection: 0
# False

# %% [markdown]
# ## Point on polygon test

# %%
coord = [(4,1), (4,5), (1,3)]
st_pt = (4, 3)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()


check_inside(coord[:-1], st_pt)
# Out:
# pt1: (4, 1)
# pt2: (4, 5)
# polygon line: [ 4  0 16]
# horizontal line: [0, 1, 3]
# intersection_point: [4. 3.]
#
# intersection: 0
#
# pt1: (4, 5)
# pt2: (1, 3)
# polygon line: [-2  3  7]
# horizontal line: [0, 1, 3]
# intersection_point: [1. 3.]
#
# intersection: 0
#
# pt1: (1, 3)
# pt2: (4, 1)
# polygon line: [ -2  -3 -11]
# horizontal line: [0, 1, 3]
# intersection_point: [1. 3.]
#
# intersection: 0
# False

# %% [markdown]
# ## Inside but Outside Polygon Test

# %%
coord = [(5,1), (5,6), (1, 6), (1, 3), (2, 3), (2, 5), (4, 5), (4, 2), (1, 2), (1, 1)]
st_pt = (3, 4)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord[:-1], st_pt)
# Out:
# pt1: (5, 1)
# pt2: (5, 6)
# polygon line: [ 5  0 25]
# horizontal line: [0, 1, 4]
# intersection_point: [5. 4.]
#
# intersection: 0
#
# pt1: (5, 6)
# pt2: (1, 6)
# polygon line: [ 0  4 24]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (1, 6)
# pt2: (1, 3)
# polygon line: [-3  0 -3]
# horizontal line: [0, 1, 4]
# intersection_point: [1. 4.]
#
# intersection: 0
#
# pt1: (1, 3)
# pt2: (2, 3)
# polygon line: [ 0 -1 -3]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (2, 3)
# pt2: (2, 5)
# polygon line: [2 0 4]
# horizontal line: [0, 1, 4]
# intersection_point: [2. 4.]
#
# intersection: 0
#
# pt1: (2, 5)
# pt2: (4, 5)
# polygon line: [  0  -2 -10]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (4, 5)
# pt2: (4, 2)
# polygon line: [ -3   0 -12]
# horizontal line: [0, 1, 4]
# intersection_point: [4. 4.]
#
# intersection: 0
#
# pt1: (4, 2)
# pt2: (1, 2)
# polygon line: [0 3 6]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (1, 2)
# pt2: (1, 1)
# polygon line: [-1  0 -1]
# horizontal line: [0, 1, 4]
# intersection_point: [1. 4.]
#
# intersection: 0
#
# pt1: (1, 1)
# pt2: (5, 1)
# polygon line: [ 0 -4 -4]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
# False

# %% [markdown]
# ## Isosceles Triangle Test

# %%
coord = [(5,3), (1,5), (1, 1)]
st_pt = (3, 3)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord[:-1], st_pt)
# Out:
# pt1: (5, 3)
# pt2: (1, 5)
# polygon line: [ 2  4 22]
# horizontal line: [0, 1, 3]
# intersection_point: [5. 3.]
#
# intersection: 0
#
# pt1: (1, 5)
# pt2: (1, 1)
# polygon line: [-4  0 -4]
# horizontal line: [0, 1, 3]
# intersection_point: [1. 3.]
#
# intersection: 0
#
# pt1: (1, 1)
# pt2: (5, 3)
# polygon line: [ 2 -4 -2]
# horizontal line: [0, 1, 3]
# intersection_point: [5. 3.]
#
# intersection: 0
# False

# %% [markdown]
# ## Outside Vertex Test

# %%
coord = [(5,1), (5,5), (3,5), (3,2), (2,2), (2,4), (1,3), (1, 1)]
st_pt = (4, 4)
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord[:-1], st_pt)
# Out:
# pt1: (5, 1)
# pt2: (5, 5)
# polygon line: [ 4  0 20]
# horizontal line: [0, 1, 4]
# intersection_point: [5. 4.]
#
# intersection: 0
#
# pt1: (5, 5)
# pt2: (3, 5)
# polygon line: [ 0  2 10]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (3, 5)
# pt2: (3, 2)
# polygon line: [-3  0 -9]
# horizontal line: [0, 1, 4]
# intersection_point: [3. 4.]
#
# intersection: 0
#
# pt1: (3, 2)
# pt2: (2, 2)
# polygon line: [0 1 2]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
#
# pt1: (2, 2)
# pt2: (2, 4)
# polygon line: [2 0 4]
# horizontal line: [0, 1, 4]
# intersection_point: [2. 4.]
#
# intersection: 0
#
# pt1: (2, 4)
# pt2: (1, 3)
# polygon line: [-1  1  2]
# horizontal line: [0, 1, 4]
# intersection_point: [2. 4.]
#
# intersection: 0
#
# pt1: (1, 3)
# pt2: (1, 1)
# polygon line: [-2  0 -2]
# horizontal line: [0, 1, 4]
# intersection_point: [1. 4.]
#
# intersection: 0
#
# pt1: (1, 1)
# pt2: (5, 1)
# polygon line: [ 0 -4 -4]
# horizontal line: [0, 1, 4]
# intersection_point: None
#
# intersection: 0
# False

# %% [markdown]
# ## Complex Polygon Test

# %%
def draw_polygon(n):
    # https://stackoverflow.com/questions/45831084/creating-a-polygon-in-python
    sort_tups = []
    x = np.random.randint(0,50,n)
    y = np.random.randint(0,50,n)

    ##computing the (or a) 'center point' of the polygon
    center_point = [np.sum(x)/n, np.sum(y)/n]

    angles = np.arctan2(x-center_point[0],y-center_point[1])

    ##sorting the points:
    sort_tups = sorted([(i,j,k) for i,j,k in zip(x,y,angles)], key = lambda t: t[2])

    ##making sure that there are no duplicates:
    if len(sort_tups) != len(set(sort_tups)):
        raise Exception('two equal coordinates -- exiting')

    x,y,angles = zip(*sort_tups)
    x = list(x)
    y = list(y)
    
    return [(i, j) for i, j in zip(x, y)]

# %%
coord = draw_polygon(15)
st_pt = np.rint(np.mean(coord, axis=0))
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord[:-1], st_pt)
# Out:
# pt1: (12, 1)
# pt2: (13, 9)
# polygon line: [ 8 -1 95]
# horizontal line: [0, 1, 22.0]
# intersection_point: [14.625 22.   ]
#
# intersection: 0
#
# pt1: (13, 9)
# pt2: (12, 8)
# polygon line: [-1  1 -4]
# horizontal line: [0, 1, 22.0]
# intersection_point: [26. 22.]
#
# intersection: 0
#
# pt1: (12, 8)
# pt2: (9, 4)
# polygon line: [ -4   3 -24]
# horizontal line: [0, 1, 22.0]
# intersection_point: [22.5 22. ]
#
# intersection: 0
#
# pt1: (9, 4)
# pt2: (0, 30)
# polygon line: [ 26   9 270]
# horizontal line: [0, 1, 22.0]
# intersection_point: [ 2.76923077 22.        ]
#
# intersection: 0
#
# pt1: (0, 30)
# pt2: (1, 35)
# polygon line: [  5  -1 -30]
# horizontal line: [0, 1, 22.0]
# intersection_point: [-1.6 22. ]
#
# intersection: 0
#
# pt1: (1, 35)
# pt2: (0, 45)
# polygon line: [10  1 45]
# horizontal line: [0, 1, 22.0]
# intersection_point: [ 2.3 22. ]
#
# intersection: 0
#
# pt1: (0, 45)
# pt2: (9, 48)
# polygon line: [   3   -9 -405]
# horizontal line: [0, 1, 22.0]
# intersection_point: [-69.  22.]
#
# intersection: 0
#
# pt1: (9, 48)
# pt2: (20, 46)
# polygon line: [  -2  -11 -546]
# horizontal line: [0, 1, 22.0]
# intersection_point: [152.  22.]
#
# intersection: 0
#
# pt1: (20, 46)
# pt2: (23, 40)
# polygon line: [  -6   -3 -258]
# horizontal line: [0, 1, 22.0]
# intersection_point: [32. 22.]
#
# intersection: 0
#
# pt1: (23, 40)
# pt2: (31, 33)
# polygon line: [  -7   -8 -481]
# horizontal line: [0, 1, 22.0]
# intersection_point: [43.57142857 22.        ]
#
# intersection: 0
#
# pt1: (31, 33)
# pt2: (49, 9)
# polygon line: [  -24   -18 -1338]
# horizontal line: [0, 1, 22.0]
# intersection_point: [39.25 22.  ]
#
# intersection: 1
#
# pt1: (49, 9)
# pt2: (26, 16)
# polygon line: [  7  23 550]
# horizontal line: [0, 1, 22.0]
# intersection_point: [ 6.28571429 22.        ]
#
# intersection: 1
#
# pt1: (26, 16)
# pt2: (39, 3)
# polygon line: [ -13  -13 -546]
# horizontal line: [0, 1, 22.0]
# intersection_point: [20. 22.]
#
# intersection: 2
#
# pt1: (39, 3)
# pt2: (36, 3)
# polygon line: [0 3 9]
# horizontal line: [0, 1, 22.0]
# intersection_point: None
#
# intersection: 2
#
# pt1: (36, 3)
# pt2: (12, 1)
# polygon line: [-2 24  0]
# horizontal line: [0, 1, 22.0]
# intersection_point: [264.  22.]
#
# intersection: 2
# False

# %%
coord = draw_polygon(3)
st_pt = np.rint(np.mean(coord, axis=0))
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys)
plt.plot(st_pt[0], st_pt[1], 'ro')
plt.show()

check_inside(coord, st_pt)
# Out:
# pt1: (21, 20)
# pt2: (26, 37)
# polygon line: [ 17  -5 257]
# horizontal line: [0, 1, 29.0]
# intersection_point: [23.64705882 29.        ]
#
# intersection: 0
#
# pt1: (26, 37)
# pt2: (30, 31)
# polygon line: [  -6   -4 -304]
# horizontal line: [0, 1, 29.0]
# intersection_point: [31.33333333 29.        ]
#
# intersection: 0
#
# pt1: (30, 31)
# pt2: (21, 20)
# polygon line: [-11   9 -51]
# horizontal line: [0, 1, 29.0]
# intersection_point: [28.36363636 29.        ]
#
# intersection: 1
#
# pt1: (21, 20)
# pt2: (21, 20)
# polygon line: [0 0 0]
# horizontal line: [0, 1, 29.0]
# intersection_point: None
#
# intersection: 1
#
# 1
# True

# %% [markdown]
# ## Benchmarking

# %%
def benchmark(algorithm, polygon, st_pt):
    # Setup
    start_time = time.perf_counter()
    
    # Do benchmarking
    algorithm(polygon, st_pt)
    
    end_time = time.perf_counter()
    elapsed = end_time - start_time
    return elapsed

# %%
benchmark(check_inside, coord, st_pt)
# Out:
# pt1: (21, 20)
# pt2: (26, 37)
# polygon line: [ 17  -5 257]
# horizontal line: [0, 1, 29.0]
# intersection_point: [23.64705882 29.        ]
#
# intersection: 0
#
# pt1: (26, 37)
# pt2: (30, 31)
# polygon line: [  -6   -4 -304]
# horizontal line: [0, 1, 29.0]
# intersection_point: [31.33333333 29.        ]
#
# intersection: 0
#
# pt1: (30, 31)
# pt2: (21, 20)
# polygon line: [-11   9 -51]
# horizontal line: [0, 1, 29.0]
# intersection_point: [28.36363636 29.        ]
#
# intersection: 1
#
# pt1: (21, 20)
# pt2: (21, 20)
# polygon line: [0 0 0]
# horizontal line: [0, 1, 29.0]
# intersection_point: None
#
# intersection: 1
#
# 1
# 0.0036487719044089317
